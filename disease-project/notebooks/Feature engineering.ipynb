# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read data

# %%
df_severity = pd.read_csv("../data/processed/Symptom-severity.csv",index_col="Symptom")
df = pd.read_csv("../data/processed/merged_data.csv")

# %%
df_severity
# Out:
#                       weight
# Symptom
# itching                    1
# skin_rash                  3
# nodal_skin_eruptions       4
# continuous_sneezing        4
# shivering                  5
# ...                      ...
# blister                    4
# red_sore_around_nose       2
# yellow_crust_ooze          3
# prognosis                  5
# no symptoms                0
#
# [133 rows x 1 columns]

# %%
def missing_values(df):
    df = df.fillna("no symptoms")
    return df

# %%
def weight_symptoms(df_severity,df):
    for symp in df_severity.index.tolist():
        weight = df_severity.loc[symp][0]
        df = df.replace(symp,weight)
    return df

# %%
def split(df):
    X = df.iloc[:,1:]
    Y = df.iloc[:,0]
    
    x_train, x_test,y_train, ytest = train_test_split(X, Y, test_size=0.33, random_state=42)
    return (x_train,
            x_test,
            y_train,
            ytest)

# %%
def pipeline(df):
    if "Disease" in df.columns:
        df =df.iloc[:,:-5]
        df = missing_values(df)
        df = weight_symptoms(df_severity,df)
        (x_train,
         x_test,
         y_train,
         y_test) = split(df)
        return x_train
    else:
        df = missing_values(df)
        df = weight_symptoms(df)

# %%
# Out:
# 1   itching
# 3   skin_rash
# 4   nodal_skin_eruptions
# 4   continuous_sneezing
# 5   shivering
# 3   chills
# 3   joint_pain
# 5   stomach_pain
# 3   acidity
# 4   ulcers_on_tongue
# 3   muscle_wasting
# 5   vomiting
# 6   burning_micturition
# 6   spotting_urination
# 4   fatigue
# 3   weight_gain
# 4   anxiety
# 5   cold_hands_and_feets
# 3   mood_swings
# 3   weight_loss
# 5   restlessness
# 2   lethargy
# 6   patches_in_throat
# 5   irregular_sugar_level
# 4   cough
# 7   high_fever
# 3   sunken_eyes
# 4   breathlessness
# 3   sweating
# 4   dehydration
# 5   indigestion
# 3   headache
# 3   yellowish_skin
# 4   dark_urine
# 5   nausea
# 4   loss_of_appetite
# 4   pain_behind_the_eyes
# 3   back_pain
# 4   constipation
# 4   abdominal_pain
# 6   diarrhoea
# 5   mild_fever
# 4   yellow_urine
# 4   yellowing_of_eyes
# 6   acute_liver_failure
# 6   fluid_overload
# 7   swelling_of_stomach
# 6   swelled_lymph_nodes
# 6   malaise
# 5   blurred_and_distorted_vision
# 5   phlegm
# 4   throat_irritation
# 5   redness_of_eyes
# 4   sinus_pressure
# 5   runny_nose
# 5   congestion
# 7   chest_pain
# 7   weakness_in_limbs
# 5   fast_heart_rate
# 5   pain_during_bowel_movements
# 6   pain_in_anal_region
# 5   bloody_stool
# 6   irritation_in_anus
# 5   neck_pain
# 4   dizziness
# 4   cramps
# 4   bruising
# 4   obesity
# 5   swollen_legs
# 5   swollen_blood_vessels
# 5   puffy_face_and_eyes
# 6   enlarged_thyroid
# 5   brittle_nails
# 5   swollen_extremeties
# 4   excessive_hunger
# 5   extra_marital_contacts
# 4   drying_and_tingling_lips
# 4   slurred_speech
# 3   knee_pain
# 2   hip_joint_pain
# 2   muscle_weakness
# 4   stiff_neck
# 5   swelling_joints
# 5   movement_stiffness
# 6   spinning_movements
# 4   loss_of_balance
# 4   unsteadiness
# 4   weakness_of_one_body_side
# 3   loss_of_smell
# 4   bladder_discomfort
# 5   foul_smell_ofurine
# 6   continuous_feel_of_urine
# 5   passage_of_gases
# 4   internal_itching
# 5   toxic_look_(typhos)
# 3   depression
# 2   irritability
# 2   muscle_pain
# 2   altered_sensorium
# 3   red_spots_over_body
# 4   belly_pain
# 6   abnormal_menstruation
# 6   dischromic_patches
# 4   watering_from_eyes
# 5   increased_appetite
# 4   polyuria
# 5   family_history
# 4   mucoid_sputum
# 4   rusty_sputum
# 3   lack_of_concentration
# 3   visual_disturbances
# 5   receiving_blood_transfusion
# 2   receiving_unsterile_injections
# 7   coma
# 6   stomach_bleeding
# 4   distention_of_abdomen
# 5   history_of_alcohol_consumption
# 5   blood_in_sputum
# 6   prominent_veins_on_calf
# 4   palpitations
# 2   painful_walking
# 2   pus_filled_pimples
# 2   blackheads
# 2   scurring
# 3   skin_peeling
# 2   silver_like_dusting
# 2   small_dents_in_nails
# 2   inflammatory_nails
# 4   blister
# 2   red_sore_around_nose
# 3   yellow_crust_ooze
# 5   prognosis
# 0   no symptoms

# %%
x_train
# Out:
#       Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  Symptom_6  \
# 4479          6          4          6          0          0          0
# 1694          1          5          3          7          3          4
# 573           1          3          5          6          6          0
# 1236          3          7          4          4          3          0
# 4332          2          2          2          0          0          0
# ...         ...        ...        ...        ...        ...        ...
# 4426          3          2          2          2          0          0
# 466           1          5          3          5          4          4
# 3092          3          5          4          3          4          7
# 3772          3          3          5          3          6          5
# 860           4          3          5          2          5          5
#
#       Symptom_7  Symptom_8  Symptom_9  Symptom_10  ...  Symptom_13  \
# 4479          0          0          0           0  ...           0
# 1694          4          0          0           0  ...           0
# 573           0          0          0           0  ...           0
# 1236          0          0          0           0  ...           0
# 4332          0          0          0           0  ...           0
# ...         ...        ...        ...         ...  ...         ...
# 4426          0          0          0           0  ...           0
# 466           4          0          0           0  ...           0
# 3092          4          3          4           5  ...           6
# 3772          4          2          2           6  ...           0
# 860           4          4          5           4  ...           0
#
#       Symptom_14  Symptom_15  Symptom_16  Symptom_17           Precaution_1  \
# 4479           0           0           0           0  drink plenty of water
# 1694           0           0           0           0  drink plenty of water
# 573            0           0           0           0        stop irritation
# 1236           0           0           0           0             meditation
# 4332           0           0           0           0             bath twice
# ...          ...         ...         ...         ...                    ...
# 4426           0           0           0           0             bath twice
# 466            0           0           0           0             cold baths
# 3092           5           7           5           0            cover mouth
# 3772           0           0           0           0            eat healthy
# 860            0           0           0           0     have balanced diet
#
#                    Precaution_2                       Precaution_3  \
# 4479  increase vitamin c intake              drink cranberry juice
# 1694       consume milk thistle  eat fruits and high fiberous food
# 573    consult nearest hospital                   stop taking drug
# 1236                 salt baths                      reduce stress
# 4332     avoid fatty spicy food              drink plenty of water
# ...                         ...                                ...
# 4426     avoid fatty spicy food              drink plenty of water
# 466          anti itch medicine                     consult doctor
# 3092             consult doctor                         medication
# 3772                    massage                     use lemon balm
# 860                    exercise                     consult doctor
#
#                            Precaution_4  \
# 4479                    take probiotics
# 1694                         medication
# 573                           follow up
# 1236                   get proper sleep
# 4332            avoid too many products
# ...                                 ...
# 4426            avoid too many products
# 466                         eat healthy
# 3092                               rest
# 3772  take radioactive iodine treatment
# 860                           follow up
#
#                                             Description
# 4479  Urinary tract infection: An infection of the k...
# 1694  Yellow staining of the skin and sclerae (the w...
# 573   An adverse drug reaction (ADR) is an injury ca...
# 1236  Hypertension (HTN or HT), also known as high b...
# 4332  Acne vulgaris is the formation of comedones, p...
# ...                                                 ...
# 4426  Acne vulgaris is the formation of comedones, p...
# 466   Chronic cholestatic diseases, whether occurrin...
# 3092  Tuberculosis (TB) is an infectious disease usu...
# 3772  Hyperthyroidism (overactive thyroid) occurs wh...
# 860   Diabetes is a disease that occurs when your bl...
#
# [3216 rows x 22 columns]
